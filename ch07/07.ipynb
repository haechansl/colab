# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img= cv2.imread('/content/gdrive/My Drive/Colab IP/Images/flower.bmp')

# %%
output_img = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_NEAREST)

# %%
print("oriningal image", img.shape[:2])
cv2_imshow(img)
print("Nearest Neighbor Interpolation",output_img.shape[:2])
cv2_imshow(output_img)
# Out:
# oriningal image (210, 320)
# <PIL.Image.Image image mode=RGB size=320x210>
# Nearest Neighbor Interpolation (420, 640)
# <PIL.Image.Image image mode=RGB size=640x420>

# %%
img= cv2.imread('/content/gdrive/My Drive/Colab IP/Images/lena.jpg')

# %%
height,width = img.shape[:2]

# %%
M=cv2.getRotationMatrix2D(((width-1)/2.0,(height-1)/2.0),90,1)
output_img = cv2.warpAffine(img,M,(width*1,height*1),flags=cv2.INTER_LINEAR)

# %%
print("oriningal image", img.shape[:2])
cv2_imshow(img)
print("Nearest Neighbor Interpolation",output_img.shape[:2])
cv2_imshow(output_img)
# Out:
# oriningal image (512, 512)
# <PIL.Image.Image image mode=RGB size=512x512>
# Nearest Neighbor Interpolation (512, 512)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
img= cv2.imread('/content/gdrive/My Drive/Colab IP/Images/lena.jpg')

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
flipVertical = cv2.flip(img, 0)
flipHorizontal = cv2.flip(img, 1)
flipBoth = cv2.flip(img,-1)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,4,1)
plt.title("Original image")
plt.imshow(img)
plt.axis("off")
plt.subplot(1,4,2)
plt.title("Flipped vertical image")
plt.imshow(flipVertical)
plt.axis("off")
plt.subplot(1,4,3)
plt.title("Flipped horizontal image")
plt.imshow(flipHorizontal)
plt.axis("off")
plt.subplot(1,4,4)
plt.title("Flipped both image")
plt.imshow(flipBoth)
plt.axis("off")
plt.show()
